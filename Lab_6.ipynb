# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlesJBU/OOP/blob/main/Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/data01.csv")

y = df['median_house_value'].median()
print(y)
# Out:
# 175050.0

# %%
import pandas as pd
df = pd.read_csv("/content/data01.csv")

y = df['total_rooms'].median()
print(y)

for x in df.index:
  if df.loc[x, "total_rooms"] < 500:
    df.loc[x, "total_rooms"] = y

df
# Out:
# 2035.0
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.05     37.37                  27         3885             661
# 1      -118.30     34.26                  43         1510             310
# 2      -117.81     33.78                  27         3589             507
# 3      -118.36     33.82                  28         2035              15
# 4      -119.67     36.33                  19         1241             244
# ..         ...       ...                 ...          ...             ...
# 495    -122.29     37.82                   2         2035              43
# 496    -116.31     33.65                   8         3079             558
# 497    -118.27     34.01                  43         1235             385
# 498    -122.44     37.76                  52         1968             472
# 499    -118.27     34.15                  14         1744             536
#
#      population  households  median_income  median_house_value
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/data01.csv")

print(df[df["housing_median_age"] < 25])
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4      -119.67     36.33                  19         1241             244
# 7      -120.65     35.48                  19         2310             471
# 8      -122.84     38.40                  15         3080             617
# 13     -117.03     32.97                  16         3936             694
# 16     -120.81     37.53                  15          570             123
# ..         ...       ...                 ...          ...             ...
# 487    -118.19     33.82                  11          872             203
# 494    -117.07     34.05                  14         5764            1006
# 495    -122.29     37.82                   2          158              43
# 496    -116.31     33.65                   8         3079             558
# 499    -118.27     34.15                  14         1744             536
#
#      population  households  median_income  median_house_value
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("/content/data01.csv")

df.plot(kind = 'scatter', x = 'total_rooms', y = 'total_bedrooms')
# Out:
# <Axes: xlabel='total_rooms', ylabel='total_bedrooms'>
